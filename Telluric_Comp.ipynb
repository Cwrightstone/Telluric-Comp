# %%
"""
Welcome to Telluric_Comp_v1!!
THIS IS A COMBO OF THE SDL AND CIS GRAPH PYTHON FILES

Creator - Chris Wrightstone


Instructions
1. Input your data, SDLs and CIS data
2.
3.
4.
5.


"""

# %%
import pandas as pd
import csv
import datetime
import numpy as np
import matplotlib.pyplot as plt 
import os
import re
import plotly.express as px
import plotly.graph_objects as go

# %%
"""
1. Is there a way to use the orginal headers???
2. 

"""

# %%
# USE THIS TO REVIEW ALL INPUT DATA FOR THE US RAW DATA
UsRaw = pd.read_csv('SDL data/03302022_udl1_sn002869.csv')
UsRaw.head(50)

# %%
#PLOT US SDL IN PLOTLY
fig = px.line(UsRaw, x='Date/Time(Eastern Daylight Time UTC-4:00)', y='DC ', range_y=[0, -3])
fig.show()

# %%
# USE THIS TO REVIEW ALL INPUT DATA FOR DS RAW DATA

# %%
# PLOT THE RAW DATA FOR THE DS SDL

# %%
# Input the SDL data
Raw_US = []
Raw_DS = []

# %%
"""
TO DO LIST

1. ADD A CONVERT FROM SVY TO CSV, MAKE A CSV TEMPLETE WITH HEADERS TO CONVERT INTO TO 
2. ADD A LINE GRAPH FOR ON, OFF IN THE Y AXIS AND X-AXIS MAKE COMMENTS AND STATIONING. 


"""

# %%
# REVIEW THE CIS DATA 
CIS = pd.read_csv('CIS data/20220303_TC DOC SURVEY_SEGMENT 3120_MT.csv')
CIS.head()
# Out:
#     0      -0.001  0.1   03/03/2022   09:52:26.050  g   00/00/0000   00:00:00  \
# 0  10       0.004  0.0   03/03/2022   09:52:55.437  g   00/00/0000   00:00:00
# 1  20      -0.014  0.0   03/03/2022   09:52:59.035  g   00/00/0000   00:00:00
# 2  30      -0.019  0.0   03/03/2022   09:53:02.534  g   00/00/0000   00:00:00
# 3  40       0.001  0.0   03/03/2022   09:53:06.732  g   00/00/0000   00:00:00
# 4  50      -0.004  0.0   03/03/2022   09:53:28.622  g   00/00/0000   00:00:00
#
#    Unnamed: 9  41.34487534  -82.05918121  754.3  1.2   D  \
# 0         NaN    41.344963    -82.059181  754.1  1.1   D
# 1         NaN    41.344910    -82.059189  753.5  1.1   D
# 2         NaN    41.344929    -82.059181  753.7  1.1   D
# 3         NaN    41.344963    -82.059181  753.8  1.1
# 4         NaN    41.344982    -82.059181  754.1  1.1   D
#
#           START DOC SURVEY. NORTH. 187
# 0  183. ABOVEGRADE TAP. START DRIVEWAY
# 1                                  NaN
# ...

# %%
#PLOT THE CIS DATA
CIS_Graph = px.line(CIS, x='START DOC SURVEY. NORTH. 187', y='-0.001', range_y=[-.2, .1])
CIS_Graph.show()

# %%
# Move the SDL data to the spreadsheet for comp
def SDL():
    US_SDL = []
    DS_SDL = []
    for data in US_SDL:
